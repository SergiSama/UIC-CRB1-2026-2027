# %% [markdown]
# <a href="https://colab.research.google.com/github/SergiSama/UIC-CRB1-2026-2027/blob/main/CRB1_2026_2027_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Notebooks
#
#
# ##MODULE 1
#
# [Session 2 - Python Basics - Unified version](https://github.com/SergiSama/UIC-CRB1-2026-2027/blob/main/m1_python_basics.ipynb)
#
# [Session 2 - Numpy - Unified version](https://github.com/SergiSama/UIC-CRB1-2026-2027/blob/main/m1_numpy.ipynb)
#
# [Session 3 - Pandas - Student version](https://github.com/SergiSama/UIC-CRB1-2026-2027/blob/main/m1_pandas_student.ipynb)
#
# [Session 3 - Pandas - Instructor version](https://github.com/SergiSama/UIC-CRB1-2026-2027/blob/main/m1_pandas_instructor.ipynb)
#
# [Session 3 - Matplotlb - Student version](https://github.com/SergiSama/UIC-CRB1-2026-2027/blob/main/m1_matplotlib_student.ipynb)
#
# [Session 3 - Matplotlb - Instructor version](https://github.com/SergiSama/UIC-CRB1-2026-2027/blob/main/m1_matplotlib_instructor.ipynb)
#
# [Sessions 1-3 Recap - Student version](https://github.com/SergiSama/UIC-CRB1-2026-2027/blob/main/m1_practice_exercises_student.ipynb)
#
# [Sessions 1-3 Recap - Instructor version](https://github.com/SergiSama/UIC-CRB1-2026-2027/blob/main/m1_practice_exercises_instructor.ipynb)
#
# ##MODULE 2
#
#
#
#
# ## Aurélien Géron's Hands-on Machine Learning with...
#
# [Aurélien Géron's Index Notebook](https://colab.research.google.com/github/ageron/handson-mlp/blob/main/index.ipynb)

# %% [markdown]
# Instructions for instructor:
#
# To add links to notebooks, share the document from Google Drive web interface for General Access / Anyone with the link, copy the link and add the entry in cell below.
#
# Link from Google Drive has this form:
#
# https://drive.google.com/file/d/16kXSzRDjn2UeqaWLI5EM0t1386piQQ9E/view?usp=sharing
#
# In the list below the format must be:
#
# https://colab.research.google.com/drive/16kXSzRDjn2UeqaWLI5EM0t1386piQQ9E

# %% [markdown]
# [Test your access to Google Drive](https://colab.research.google.com/drive/1-ZmN2y_HRUtJKRgYzctriCNwHKpZ-eig)
